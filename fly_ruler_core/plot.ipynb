# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib widget

df = pd.read_csv('output.csv')

headers = [
    'npos(ft)', 'epos(ft)',
    "altitude(ft)",
    "phi(degree)", "theta(degree)", "psi(degree)",
    "velocity(ft/s)",
    "alpha(degree)", "beta(degree)",
    "p(degree/s)", "q(degree/s)", "r(degree/s)",
    "nx(g)", "ny(g)", "nz(g)",
    "mach", "qbar(lb/ft ft)", "ps(lb/ft ft)"]

plt.figure(figsize=(16, 26))

def draw(index):
    plt.subplot(6, 3, index + 1)
    plt.plot(df['time(s)'], df[headers[index]])
    plt.title(f'Time vs {headers[index]}')
    plt.xlabel('Time (s)')
    plt.ylabel(headers[index])

for index, _h in enumerate(headers):
    draw(index)

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib widget

df = pd.read_csv('output.csv')

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.plot(df['npos(ft)'], df['epos(ft)'], df["altitude(ft)"], label='Trajectory')

ax.set_title('Trajectory in 3D')
ax.set_xlabel('npos (ft)')
ax.set_ylabel('epos (ft)')
ax.set_zlabel('altitude (ft)')

ax.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib widget

df = pd.read_csv('output_flap.csv')

headers = [
    'd_lef']

plt.figure(figsize=(3, 3))

def draw(index):
    plt.subplot(1, 1, index + 1)
    plt.plot(df['time(s)'], df[headers[index]])
    plt.title(f'Time vs {headers[index]}')
    plt.xlabel('Time (s)')
    plt.ylabel(headers[index])

for index, _h in enumerate(headers):
    draw(index)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib widget

df = pd.read_csv('output_control.csv')

headers = [
    'thrust', "ele", 'ail', 'rud']

plt.figure(figsize=(10, 20))

def draw(index):
    plt.subplot(4, 1, index + 1)
    plt.plot(df['time(s)'], df[headers[index]])
    plt.title(f'Time vs {headers[index]}')
    plt.xlabel('Time (s)')
    plt.ylabel(headers[index])

for index, _h in enumerate(headers):
    draw(index)

plt.tight_layout()
plt.show()

# %% [markdown]
# [fly_ruler_core\src\parts\block.rs:148] &model_output = ModelOutput {
#     state_dot: [
#         500.00000000000006,
#         0.0,
#         0.0, // alt
#         0.0,
#         0.0,
#         0.0,
#         1.3317308808282747e-6, // vel_dot
#         0.001012520911955968, // alpha_dot
#         -inf, // beta_dot
#         6.807526254162831e-8,
#         -2.960163682176643e-7,
#         -1.1188430196268333e-5,
#     ],
#     state_extend: [
#         0.07776936367066069,
#         -0.01297077168928622,
#         0.9814273698431928,
#         0.47339470537382267,
#         187.31921181853733,
#         1193.1867197904146,
#     ],
# }

# %% [markdown]
# [fly_ruler_core\src\parts\block.rs:149] &model_output = ModelOutput {
#     state_dot: [
#         500.0,
#         0.0,
#         -7.105427357601002e-15,
#         0.0,
#         0.0,
#         0.0,
#         1.3306881257180159e-6, // vel_dot
#         1.2520945587010148e-5, // alpha_dot
#         -0.0008475102214528507, // beta_dot
#         6.807641223941765e-8,
#         -2.9605501771809764e-7,
#         -1.11884466408613e-5,
#     ],
#     state_extend: [
#         0.07897809040504986,
#         -0.01317073135843928,
#         0.9966811604644773,
#         0.47339470537382267,
#         187.31921181853733,
#         1193.1867197904146,
#     ],
# }

# %%
a = [2239, 2151, 1310, 7560.30, 13261, 3805, 210, 2000, 10879, 10404, 2978.32]
sum(a)
# Out:
# 56797.62
